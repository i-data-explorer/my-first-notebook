# %% [markdown]
# # Welcome to Data Explorer
#
# ### 1. Introduction
#
# The Data Explorer Catalog consists of sample datasets and notebooks which can be deployed using the dashboard interface and accessed through Jupyterhub. These notebooks and datasets can be modified and reused as required.
#
# ### 2. Objective
#
# This notebook explains the usage of data explorer, including
#
# 1. Deploying a Dataset
# 2. Accessing the dataset from notebook

# %% [markdown]
# ### 3. Navigating the catalog
#
# The Catalog can be navigated through the following
#
# 1. Filters shown on the left
# 2. Search bar on the top
# 3. Scrolling through the collection of all notebooks and datasets
#
# ![dashboard-2.JPG](attachment:dashboard-2.JPG)

# %% [markdown]
# ### 4. How to deploy a dataset?
#
# 1. Click the chosen dataset in the catalog. For this demonstration, "Flower Classification Data" is used.
#
# ![deploy_flower_data-2.JPG](attachment:deploy_flower_data-2.JPG)

# %% [markdown]
# 2. Deploy the "Flower Classification Data" by clicking the deploy button.
#
# ![deploy_flower_data.JPG](attachment:deploy_flower_data.JPG)

# %% [markdown]
# 3. The path to the dataset is displayed as shown, this can be used to navigate to the dataset
#
# ![note_path-2.JPG](attachment:note_path-2.JPG)

# %% [markdown]
# ### 7. How to access the deployed Datasets?
#
# The deployed dataset can be accessed using the location which has been mentioned after the dataset deployment step, and can be found in the jupyterhub tree.
#
# For the demonstration, the Flower Classification Dataset can be accessed as shown.
#
# **Note**: Flower Classification Dataset must be deployed before running the cell below

# %%
# !pip install pandas
import pandas as pd
import os

#The dataset is found under /home/jupyter-user/flower_classification_dataset/flower-calssification-dataset

df = pd.read_csv("/home/jupyter-user/flower_classification_dataset/flower-calssification-dataset/iris_dataset.csv")
df.head()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
